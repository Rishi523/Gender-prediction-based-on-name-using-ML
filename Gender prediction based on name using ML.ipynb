# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
maledata = pd.read_csv("/Users/rishithraocheeti/Downloads/Dataset-Indian-Names-master/Indian-Male-Names.csv")

# %%
femaledata=pd.read_csv("/Users/rishithraocheeti/Downloads/Dataset-Indian-Names-master/Indian-Female-Names.csv")

# %%
maledata.head()
# Out:
#               name gender    race
# 0          barjraj      m  indian
# 1     ramdin verma      m  indian
# 2  sharat chandran      m  indian
# 3  birender mandal      m  indian
# 4             amit      m  indian

# %%
femaledata.head()
# Out:
#               name gender    race
# 0          shivani      f  indian
# 1             isha      f  indian
# 2  smt shyani devi      f  indian
# 3            divya      f  indian
# 4            mansi      f  indian

# %%
data=pd.concat([maledata,femaledata])

# %%
data
# Out:
#                             name gender    race
# 0                        barjraj      m  indian
# 1                   ramdin verma      m  indian
# 2                sharat chandran      m  indian
# 3                birender mandal      m  indian
# 4                           amit      m  indian
# ...                          ...    ...     ...
# 15377                 saroj devi      f  indian
# 15378              naina @ geeta      f  indian
# 15379  manju d/0 baboo lal jatav      f  indian
# 15380                    shivani      f  indian
# 15381                      nayna      f  indian
#
# [30227 rows x 3 columns]

# %%
data=data.drop(columns=["race"])

# %%
data
# Out:
#                             name gender
# 0                        barjraj      m
# 1                   ramdin verma      m
# 2                sharat chandran      m
# 3                birender mandal      m
# 4                           amit      m
# ...                          ...    ...
# 15377                 saroj devi      f
# 15378              naina @ geeta      f
# 15379  manju d/0 baboo lal jatav      f
# 15380                    shivani      f
# 15381                      nayna      f
#
# [30227 rows x 2 columns]

# %%
gender={"m":1,"f":0}
data.gender=[gender[item] for item in data.gender]
data
# Out:
#                             name  gender
# 0                        barjraj       1
# 1                   ramdin verma       1
# 2                sharat chandran       1
# 3                birender mandal       1
# 4                           amit       1
# ...                          ...     ...
# 15377                 saroj devi       0
# 15378              naina @ geeta       0
# 15379  manju d/0 baboo lal jatav       0
# 15380                    shivani       0
# 15381                      nayna       0
#
# [30227 rows x 2 columns]

# %%
k=data.sample(frac=1)
k
# Out:
#                        name  gender
# 9940               abhishek       1
# 6097           vipin sharma       1
# 10594           chanderwati       0
# 4959               lokender       1
# 11260  satya prakesh malani       1
# ...                     ...     ...
# 6321            kishan soni       1
# 477       tarachand @ pappu       1
# 4148       abhishek @ guddu       1
# 7382                   lalu       1
# 1162                 renuka       0
#
# [30227 rows x 2 columns]

# %%
k
# Out:
#                        name  gender
# 9940               abhishek       1
# 6097           vipin sharma       1
# 10594           chanderwati       0
# 4959               lokender       1
# 11260  satya prakesh malani       1
# ...                     ...     ...
# 6321            kishan soni       1
# 477       tarachand @ pappu       1
# 4148       abhishek @ guddu       1
# 7382                   lalu       1
# 1162                 renuka       0
#
# [30227 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

# %%
names=k["name"]

# %%
names
# Out:
# 9940                 abhishek
# 6097             vipin sharma
# 10594             chanderwati
# 4959                 lokender
# 11260    satya prakesh malani
#                  ...
# 6321              kishan soni
# 477         tarachand @ pappu
# 4148         abhishek @ guddu
# 7382                     lalu
# 1162                   renuka
# Name: name, Length: 30227, dtype: object

# %%
cv=CountVectorizer()
x=cv.fit_transform(names.values.astype('U'))

# %%
cv.get_feature_names()
# Out:
# /Users/rishithraocheeti/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['02',
#  '105',
#  '11',
#  '16',
#  '18',
#  '1957975',
#  '1st',
#  '20',
#  '21',
#  '24',
#  '25',
#  '27',
#  '28',
#  '33',
#  '330',
#  '341',
#  '35',
#  '3rd',
#  '3yrs',
#  '4yrs',
#  '629',
#  '66',
#  '6month',
#  '72',
#  '7206252659',
#  '7404660980',
#  '773',
#  '78',
#  '8295508258',
#  '86',
#  '8901040854',
#  '95',
#  '9813186044',
#  '9yr',
#  'aabid',
#  'aabida',
#  'aachal',
#  'aadesh',
#  'aadil',
#  'aadish',
#  'aaditya',
#  'aaenab',
#  'aafreen',
#  'aafrin',
#  'aaftaab',
#  'aaftab',
#  'aagad',
#  'aagand',
#  'aahim',
#  'aahuja',
#  'aajad',
#  'aajam',
#  'aajiv',
#  'aakanksha',
#  'aakar',
#  'aakas',
#  'aakash',
#  'aakhon',
# ...

# %%
Y=k.gender

# %%
x_train, x_test, y_train, y_test = train_test_split(x, Y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.9133834586466165

# %%
sample=["abhinav"]
vector=cv.transform(sample).toarray()

# %%
model.predict(vector)
# Out:
# array([1])

# %%
sample=["sreeja"]
vector=cv.transform(sample).toarray()

# %%
model.predict(vector)
# Out:
# array([0])
